# %% [markdown]
# # ANSWERS

# %% [markdown]
# #1
# Flask is a web framework, it’s a Python module that lets you develop web applications easily
# Flask provides you with tools, libraries and technologies that allow you to build a web application .
# Flask is part of the categories of the micro-framework. Micro-framework are normally framework with little to
# no dependencies to external libraries.
#
# #Advantages of flask framework:
# Scalable
# Flexible
# Easy to negotiate
# Lightweight

# %% [markdown]
# #2
#
# ![Screenshot (8).png](attachment:0c610c45-2feb-4dae-af15-9c860c18a645.png)

# %% [markdown]
# ![Screenshot (10).png](attachment:0ab6962d-088d-4680-b3cd-e74e50e41f2e.png)

# %% [markdown]
# #3
#
# App Routing means mapping the URLs to a specific function that will handle the logic for that URL.
# To bind a function to an URL path we use the app.route decorator .
# App routing is used to map the specific URL with the associated function that is intended to perform some task.

# %% [markdown]
# #4
#
# ![Screenshot (11).png](attachment:9465e596-516a-4d4d-8b9c-523a650c2fcf.png)

# %% [markdown]
# #![Screenshot (12).png](attachment:160a2155-7129-49d7-8b53-52be9c60a9ee.png)

# %% [markdown]
# #5
#
# The url_for() function is used to build a URL building.
